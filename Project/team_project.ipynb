# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Import of Packages and Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display
from pathlib import Path

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, f1_score

from scipy import stats

from pycaret.classification import ClassificationExperiment
from pycaret.clustering import ClusteringExperiment

# %%
cwd = Path().cwd()
data = cwd / 'Sleep-Health-Lifestyle-Dataset'
data_csv = list(data.iterdir())[0]
df = pd.read_csv(data_csv)

# %% [markdown]
# Checking if the data has missing values. Upon checking, only the target has missing values. These missing values will be filled up with "No Sleep Disorder".

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
df['Sleep Disorder'] = df['Sleep Disorder'].fillna('No Sleep Disorder')

# %%
df['Sleep Disorder'].value_counts()
# Out:
# Sleep Disorder
# No Sleep Disorder    219
# Sleep Apnea           78
# Insomnia              77
# Name: count, dtype: int64

# %%
df.sample(10, random_state=42)
# Out:
#      Person ID  Gender  Age   Occupation  Sleep Duration  Quality of Sleep  \
# 329        330  Female   53     Engineer             8.5                 9
# 33          34    Male   31       Doctor             6.1                 6
# 15          16    Male   29       Doctor             6.0                 6
# 325        326  Female   53     Engineer             8.5                 9
# 57          58    Male   32       Doctor             6.0                 6
# 239        240    Male   44  Salesperson             6.4                 6
# 76          77    Male   33       Doctor             6.0                 6
# 119        120  Female   37   Accountant             7.2                 8
# 332        333  Female   54     Engineer             8.4                 9
# 126        127    Male   38       Lawyer             7.3                 8
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 329                       30             3       Normal         125/80
# 33                        30             8       Normal         125/80
# 15                        30             8       Normal         120/80
# 325                       30             3       Normal         125/80
# 57                        30             8       Normal         125/80
# 239                       45             7   Overweight         130/85
# 76                        30             8       Normal         125/80
# 119                       60             4       Normal         115/75
# 332                       30             3       Normal         125/80
# 126                       60             5       Normal         130/85
#
#      Heart Rate  Daily Steps     Sleep Disorder
# 329          65         5000  No Sleep Disorder
# 33           72         5000  No Sleep Disorder
# 15           70         8000  No Sleep Disorder
# 325          65         5000  No Sleep Disorder
# 57           72         5000  No Sleep Disorder
# 239          72         6000           Insomnia
# 76           72         5000  No Sleep Disorder
# 119          68         7000  No Sleep Disorder
# 332          65         5000  No Sleep Disorder
# 126          68         8000  No Sleep Disorder

# %% [markdown]
# Blood pressure is defined by both systolic and diastolic pressure, therefore it is valid to split it into two columns.

# %%
df[['bp_systolic', 'bp_diastolic']] = (
    df['Blood Pressure']
    .str
    .split('/', expand=True)
    .astype(int)
)

# %% [markdown]
# It makes sense to drop Person ID since this should not impact prediction if a person has sleeping disorder or not. Additionally, since we have already transformed the Blood Pressure column into two, namely bp_systolic and bp_diastolic, the original feature shall be dropped.

# %%
df = df.drop(columns=['Person ID', 'Blood Pressure'])

# %% [markdown]
# An overview of the statistics of the transformed data.

# %%
df.describe(include='all')
# Out:
#        Gender         Age Occupation  Sleep Duration  Quality of Sleep  \
# count     374  374.000000        374      374.000000        374.000000
# unique      2         NaN         11             NaN               NaN
# top      Male         NaN      Nurse             NaN               NaN
# freq      189         NaN         73             NaN               NaN
# mean      NaN   42.184492        NaN        7.132086          7.312834
# std       NaN    8.673133        NaN        0.795657          1.196956
# min       NaN   27.000000        NaN        5.800000          4.000000
# 25%       NaN   35.250000        NaN        6.400000          6.000000
# 50%       NaN   43.000000        NaN        7.200000          7.000000
# 75%       NaN   50.000000        NaN        7.800000          8.000000
# max       NaN   59.000000        NaN        8.500000          9.000000
#
#         Physical Activity Level  Stress Level BMI Category  Heart Rate  \
# count                374.000000    374.000000          374  374.000000
# unique                      NaN           NaN            4         NaN
# top                         NaN           NaN       Normal         NaN
# freq                        NaN           NaN          195         NaN
# mean                  59.171123      5.385027          NaN   70.165775
# std                   20.830804      1.774526          NaN    4.135676
# min                   30.000000      3.000000          NaN   65.000000
# 25%                   45.000000      4.000000          NaN   68.000000
# 50%                   60.000000      5.000000          NaN   70.000000
# 75%                   75.000000      7.000000          NaN   72.000000
# max                   90.000000      8.000000          NaN   86.000000
#
#          Daily Steps     Sleep Disorder  bp_systolic  bp_diastolic
# count     374.000000                374   374.000000    374.000000
# unique           NaN                  3          NaN           NaN
# top              NaN  No Sleep Disorder          NaN           NaN
# freq             NaN                219          NaN           NaN
# mean     6816.844920                NaN   128.553476     84.649733
# std      1617.915679                NaN     7.748118      6.161611
# min      3000.000000                NaN   115.000000     75.000000
# 25%      5600.000000                NaN   125.000000     80.000000
# 50%      7000.000000                NaN   130.000000     85.000000
# 75%      8000.000000                NaN   135.000000     90.000000
# max     10000.000000                NaN   142.000000     95.000000

# %% [markdown]
# ## Class Distribution

# %% [markdown]
# Visualizing the distribution of the different features. The distributions are shown for each feature for the following:
#
# 1. Whole dataset,
# 2. No Sleeping Disorder,
# 3. Sleep Apnea, and
# 4. Insomnia

# %%
sleep_disorders = ['All'] + df['Sleep Disorder'].unique().tolist()
dataframes = [df] + [df[df['Sleep Disorder'] == x] for x in sleep_disorders[1:]]

x, axes = plt.subplots(nrows=len(df.columns), ncols=4, figsize=(12, 30), sharey='row')
axes = axes.flatten()
col_multiplied = np.array([[x, x, x, x] for x in df.columns]).reshape(-1)
for col, (index, ax)in zip(col_multiplied, enumerate(axes)):
    if (index + 1) % 4 == 1:
        df_use = dataframes[0]
        name = sleep_disorders[0]
    if (index + 1) % 4 == 2:
        df_use = dataframes[1]
        name = sleep_disorders[1]
    if (index + 1) % 4 == 3:
        df_use = dataframes[2]
        name = sleep_disorders[2]
    if (index + 1) % 4 == 0:
        df_use = dataframes[3]
        name = sleep_disorders[3]

    if (df_use[col].dtype == 'int64') or (df_use[col].dtype == 'float64'):
        bins = 20
    else:
        bins = 'auto'

    sns.histplot(df_use, x=col, ax=ax, bins=bins)
    ax.set_ylabel(col, fontsize=10)
    ax.set_xlabel(name, fontsize=10)
    ax.tick_params(axis='x', labelrotation=45, labelsize=6)
    ax.grid(False)

    for label in ax.get_xticklabels():
        label.set_horizontalalignment('right')

plt.tight_layout()

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Data will be split into features and target where the target is the Sleep Disorder {No Sleep Disorder, Insomnia, Sleep Apnea}.
#
# Additionally, we will randomly split our train and test data in the ratio 6:4.

# %%
X = df.copy().drop(columns=['Sleep Disorder'])
y = df['Sleep Disorder'].copy()

display(X.sample(10, random_state=42))
display(y.sample(10, random_state=42))
# Out:
#      Gender  Age   Occupation  Sleep Duration  Quality of Sleep  \
# 329  Female   53     Engineer             8.5                 9
# 33     Male   31       Doctor             6.1                 6
# 15     Male   29       Doctor             6.0                 6
# 325  Female   53     Engineer             8.5                 9
# 57     Male   32       Doctor             6.0                 6
# 239    Male   44  Salesperson             6.4                 6
# 76     Male   33       Doctor             6.0                 6
# 119  Female   37   Accountant             7.2                 8
# 332  Female   54     Engineer             8.4                 9
# 126    Male   38       Lawyer             7.3                 8
#
#      Physical Activity Level  Stress Level BMI Category  Heart Rate  \
# 329                       30             3       Normal          65
# 33                        30             8       Normal          72
# 15                        30             8       Normal          70
# 325                       30             3       Normal          65
# 57                        30             8       Normal          72
# 239                       45             7   Overweight          72
# 76                        30             8       Normal          72
# 119                       60             4       Normal          68
# 332                       30             3       Normal          65
# 126                       60             5       Normal          68
#
#      Daily Steps  bp_systolic  bp_diastolic
# 329         5000          125            80
# 33          5000          125            80
# 15          8000          120            80
# 325         5000          125            80
# 57          5000          125            80
# 239         6000          130            85
# 76          5000          125            80
# 119         7000          115            75
# 332         5000          125            80
# 126         8000          130            85
# 329    No Sleep Disorder
# 33     No Sleep Disorder
# 15     No Sleep Disorder
# 325    No Sleep Disorder
# 57     No Sleep Disorder
# 239             Insomnia
# 76     No Sleep Disorder
# 119    No Sleep Disorder
# 332    No Sleep Disorder
# 126    No Sleep Disorder
# Name: Sleep Disorder, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    train_size=0.60, 
    stratify=y, 
    random_state=42
)

# %% [markdown]
# # Baseline Model: Logistic Regression

# %% [markdown]
# We will first define a baseline model where no tuning of hyperparameters will be performed. Preprocessing of data is simply applying a OneHotEncoder for the categorical data and StandardScaler for the numerical data.

# %% [markdown]
# ## Train

# %%
object_col = [col for col in df.columns if df[col].dtype == 'object' and col != 'Sleep Disorder']
int_col = [col for col in df.columns if df[col].dtype == 'int64' or df[col].dtype == 'int32']
float_col = [col for col in df.columns if df[col].dtype == 'float64']

# %%
onehotencoder = ColumnTransformer(
    [
        (
            'onehotencoder', 
            OneHotEncoder(
                handle_unknown='infrequent_if_exist', 
                sparse_output=False,
                min_frequency=0.02
            ), 
            object_col
        ),
    ],
    remainder='passthrough'
).set_output(transform='pandas')

baseline = Pipeline([
    ('onehotencoder', onehotencoder),
    ('scaler', StandardScaler().set_output(transform='pandas')),
    ('model', LogisticRegression(random_state=42))
])

baseline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('onehotencoder',
#                  ColumnTransformer(n_jobs=None, remainder='passthrough',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories='auto',
#                                                                 drop=None,
#                                                                 dtype=<class 'numpy.float64'>,
#                                                                 feature_name_combiner='concat',
#                                                                 handle_unknown='infrequent_if_exist',
#                                                                 max_categories=None,
#                                                                 min_frequency=0...
#                                    verbose_feature_names_out=True)),
#                 ('scaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('model',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=42,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %% [markdown]
# ## Metrics

# %%
baseline_accuracy = baseline.score(X_test, y_test)

# %%
pd.DataFrame(
    classification_report(
        y_test, 
        baseline.predict(X_test), 
        output_dict=True
    )
)
# Out:
#             Insomnia  No Sleep Disorder  Sleep Apnea  accuracy   macro avg  \
# precision   0.962963           0.955056     0.823529  0.926667    0.913850
# recall      0.838710           0.965909     0.903226  0.926667    0.902615
# f1-score    0.896552           0.960452     0.861538  0.926667    0.906181
# support    31.000000          88.000000    31.000000  0.926667  150.000000
#
#            weighted avg
# precision      0.929508
# recall         0.926667
# f1-score       0.926804
# support      150.000000

# %%
ConfusionMatrixDisplay.from_estimator(baseline, X_test, y_test)
plt.grid(visible=False);

# %% [markdown]
# Based on the results of the baseline model for the test data, we are seeing an accuracy of 92.67% with 11 misclassified out of the 150 test data.

# %% [markdown]
# # Tuned Model: Optimized Logistic Regression

# %% [markdown]
# ## Train

# %%
onehotencoder = ColumnTransformer(
    [
        (
            'onehotencoder', 
            OneHotEncoder(
                handle_unknown='infrequent_if_exist', 
                sparse_output=False,
                min_frequency=0.02
            ), 
            object_col
        ),
    ],
    remainder='passthrough'
).set_output(transform='pandas')

pipeline = Pipeline([
    ('onehotencoder', onehotencoder),
    ('scaler', StandardScaler().set_output(transform='pandas')),
    ('model', LogisticRegression(random_state=42))
])

param_distributions = {
    'model__penalty': [None, 'l1', 'l2', 'elasticnet'],
    'model__C': stats.loguniform(0.01, 100),
    'model__fit_intercept': [True, False],
    'model__intercept_scaling': stats.uniform(0.001, 0.999),
    'model__solver': ['saga', 'lbfgs'],
    'model__class_weight': [None, 'balanced'],
    'model__max_iter': [1000],
    'model__l1_ratio': stats.uniform(0.001, 0.999),   
}

cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

rscv = RandomizedSearchCV(
    pipeline,
    param_distributions=param_distributions,
    n_iter=100,
    scoring='accuracy',
    cv=cv,
    verbose=0,
    random_state=42,
    return_train_score=True,
    n_jobs=-1
)

rscv.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=10, random_state=42, shuffle=True),
#                    error_score=nan,
#                    estimator=Pipeline(memory=None,
#                                       steps=[('onehotencoder',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='passthrough',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('onehotencoder',
#                                                                                OneHotEncoder(categories='auto',
#                                                                                              drop=None,
#                                                                                              dtype=<class 'numpy.float64...
#                                         'model__intercept_scaling': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000218905352D0>,
#                                         'model__l1_ratio': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x00000218AA22C550>,
#                                         'model__max_iter': [1000],
#                                         'model__penalty': [None, 'l1', 'l2',
#                                                            'elasticnet'],
#                                         'model__solver': ['saga', 'lbfgs']},
#                    pre_dispatch='2*n_jobs', random_state=42, refit=True,
#                    return_train_score=True, scoring='accuracy', verbose=0)

# %%
rscv.best_params_
# Out:
# {'model__C': 0.31489116479568624,
#  'model__class_weight': None,
#  'model__fit_intercept': True,
#  'model__intercept_scaling': 0.7322619478695936,
#  'model__l1_ratio': 0.5990598257128396,
#  'model__max_iter': 1000,
#  'model__penalty': 'l2',
#  'model__solver': 'lbfgs'}

# %% [markdown]
# ## Metrics

# %%
tuned_accuracy = rscv.best_estimator_.score(X_test, y_test)

# %%
pd.DataFrame(
    classification_report(
        y_test, 
        rscv.best_estimator_.predict(X_test), 
        output_dict=True
    )
)
# Out:
#             Insomnia  No Sleep Disorder  Sleep Apnea  accuracy   macro avg  \
# precision   0.931034           0.954545     0.848485  0.926667    0.911355
# recall      0.870968           0.954545     0.903226  0.926667    0.909580
# f1-score    0.900000           0.954545     0.875000  0.926667    0.909848
# support    31.000000          88.000000    31.000000  0.926667  150.000000
#
#            weighted avg
# precision      0.927767
# recall         0.926667
# f1-score       0.926833
# support      150.000000

# %%
ConfusionMatrixDisplay.from_estimator(rscv.best_estimator_, X_test, y_test)
plt.grid(visible=False);

# %% [markdown]
# We have an optimized model where RandomizedSearchCV was used to search for better hyperparameters. The model has maintained accuracy over the test data, having an accuracy of 92.67% with misclassifying 11 out of 150.

# %% [markdown]
# # Pycaret Classification

# %%
s = ClassificationExperiment()
s.setup(
    df,
    target='Sleep Disorder',
    imputation_type=None,
    session_id=42,
    train_size=0.6,
    rare_to_value=0.02,
    fold=5,
    normalize=True,
)
# Out:
# <style type="text/css">
# #T_f69a0_row10_col1, #T_f69a0_row14_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f69a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f69a0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f69a0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f69a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f69a0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f69a0_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f69a0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f69a0_row1_col1" class="data row1 col1" >Sleep Disorder</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f69a0_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f69a0_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f69a0_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_f69a0_row3_col1" class="data row3 col1" >Insomnia: 0, No Sleep Disorder: 1, Sleep Apnea: 2</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f69a0_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_f69a0_row4_col1" class="data row4 col1" >(374, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f69a0_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_f69a0_row5_col1" class="data row5 col1" >(374, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f69a0_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_f69a0_row6_col1" class="data row6 col1" >(224, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f69a0_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_f69a0_row7_col1" class="data row7 col1" >(150, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f69a0_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_f69a0_row8_col1" class="data row8 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f69a0_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_f69a0_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f69a0_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_f69a0_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f69a0_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_f69a0_row11_col1" class="data row11 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f69a0_row12_col0" class="data row12 col0" >Maximum one-hot encoding</td>
#       <td id="T_f69a0_row12_col1" class="data row12 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f69a0_row13_col0" class="data row13 col0" >Encoding method</td>
#       <td id="T_f69a0_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f69a0_row14_col0" class="data row14 col0" >Normalize</td>
#       <td id="T_f69a0_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f69a0_row15_col0" class="data row15 col0" >Normalize method</td>
#       <td id="T_f69a0_row15_col1" class="data row15 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f69a0_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_f69a0_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f69a0_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_f69a0_row17_col1" class="data row17 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f69a0_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_f69a0_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f69a0_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_f69a0_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f69a0_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_f69a0_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f69a0_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_f69a0_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f69a0_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f69a0_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_f69a0_row22_col1" class="data row22 col1" >ff6d</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We will select the top 3 models (other than a logistic regression model) and tune them.

# %% [markdown]
# ## Compare Default Models

# %%
model_1, _, model_2, model_3 = s.compare_models(n_select=4)
# Out:
# <style type="text/css">
# #T_8507e th {
#   text-align: left;
# }
# #T_8507e_row0_col0, #T_8507e_row0_col2, #T_8507e_row1_col0, #T_8507e_row1_col1, #T_8507e_row1_col2, #T_8507e_row1_col3, #T_8507e_row1_col4, #T_8507e_row1_col5, #T_8507e_row1_col6, #T_8507e_row1_col7, #T_8507e_row2_col0, #T_8507e_row2_col1, #T_8507e_row2_col2, #T_8507e_row2_col3, #T_8507e_row2_col4, #T_8507e_row2_col5, #T_8507e_row2_col6, #T_8507e_row2_col7, #T_8507e_row3_col0, #T_8507e_row3_col1, #T_8507e_row3_col2, #T_8507e_row3_col3, #T_8507e_row3_col4, #T_8507e_row3_col5, #T_8507e_row3_col6, #T_8507e_row3_col7, #T_8507e_row4_col0, #T_8507e_row4_col1, #T_8507e_row4_col2, #T_8507e_row4_col3, #T_8507e_row4_col4, #T_8507e_row4_col5, #T_8507e_row4_col6, #T_8507e_row4_col7, #T_8507e_row5_col0, #T_8507e_row5_col1, #T_8507e_row5_col2, #T_8507e_row5_col3, #T_8507e_row5_col4, #T_8507e_row5_col5, #T_8507e_row5_col6, #T_8507e_row5_col7, #T_8507e_row6_col0, #T_8507e_row6_col1, #T_8507e_row6_col2, #T_8507e_row6_col3, #T_8507e_row6_col4, #T_8507e_row6_col5, #T_8507e_row6_col6, #T_8507e_row6_col7, #T_8507e_row7_col0, #T_8507e_row7_col1, #T_8507e_row7_col2, #T_8507e_row7_col3, #T_8507e_row7_col4, #T_8507e_row7_col5, #T_8507e_row7_col6, #T_8507e_row7_col7, #T_8507e_row8_col0, #T_8507e_row8_col1, #T_8507e_row8_col3, #T_8507e_row8_col4, #T_8507e_row8_col5, #T_8507e_row8_col6, #T_8507e_row8_col7, #T_8507e_row9_col0, #T_8507e_row9_col1, #T_8507e_row9_col2, #T_8507e_row9_col3, #T_8507e_row9_col4, #T_8507e_row9_col5, #T_8507e_row9_col6, #T_8507e_row9_col7, #T_8507e_row10_col0, #T_8507e_row10_col1, #T_8507e_row10_col2, #T_8507e_row10_col3, #T_8507e_row10_col4, #T_8507e_row10_col5, #T_8507e_row10_col6, #T_8507e_row10_col7, #T_8507e_row11_col0, #T_8507e_row11_col1, #T_8507e_row11_col2, #T_8507e_row11_col3, #T_8507e_row11_col4, #T_8507e_row11_col5, #T_8507e_row11_col6, #T_8507e_row11_col7, #T_8507e_row12_col0, #T_8507e_row12_col1, #T_8507e_row12_col2, #T_8507e_row12_col3, #T_8507e_row12_col4, #T_8507e_row12_col5, #T_8507e_row12_col6, #T_8507e_row12_col7, #T_8507e_row13_col0, #T_8507e_row13_col1, #T_8507e_row13_col2, #T_8507e_row13_col3, #T_8507e_row13_col4, #T_8507e_row13_col5, #T_8507e_row13_col6, #T_8507e_row13_col7, #T_8507e_row14_col0, #T_8507e_row14_col1, #T_8507e_row14_col2, #T_8507e_row14_col3, #T_8507e_row14_col4, #T_8507e_row14_col5, #T_8507e_row14_col6, #T_8507e_row14_col7, #T_8507e_row15_col0, #T_8507e_row15_col1, #T_8507e_row15_col2, #T_8507e_row15_col3, #T_8507e_row15_col4, #T_8507e_row15_col5, #T_8507e_row15_col6, #T_8507e_row15_col7 {
#   text-align: left;
# }
# #T_8507e_row0_col1, #T_8507e_row0_col3, #T_8507e_row0_col4, #T_8507e_row0_col5, #T_8507e_row0_col6, #T_8507e_row0_col7, #T_8507e_row8_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_8507e_row0_col8, #T_8507e_row1_col8, #T_8507e_row2_col8, #T_8507e_row3_col8, #T_8507e_row4_col8, #T_8507e_row5_col8, #T_8507e_row6_col8, #T_8507e_row7_col8, #T_8507e_row8_col8, #T_8507e_row9_col8, #T_8507e_row10_col8, #T_8507e_row11_col8, #T_8507e_row13_col8, #T_8507e_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_8507e_row12_col8, #T_8507e_row15_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_8507e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8507e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8507e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8507e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8507e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8507e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8507e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8507e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8507e_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_8507e_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8507e_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_8507e_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8507e_row0_col1" class="data row0 col1" >0.8930</td>
#       <td id="T_8507e_row0_col2" class="data row0 col2" >0.9132</td>
#       <td id="T_8507e_row0_col3" class="data row0 col3" >0.8930</td>
#       <td id="T_8507e_row0_col4" class="data row0 col4" >0.9052</td>
#       <td id="T_8507e_row0_col5" class="data row0 col5" >0.8940</td>
#       <td id="T_8507e_row0_col6" class="data row0 col6" >0.8147</td>
#       <td id="T_8507e_row0_col7" class="data row0 col7" >0.8190</td>
#       <td id="T_8507e_row0_col8" class="data row0 col8" >0.0720</td>
#     </tr>
#     <tr>
#       <th id="T_8507e_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_8507e_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_8507e_row1_col1" class="data row1 col1" >0.8886</td>
#       <td id="T_8507e_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_8507e_row1_col3" class="data row1 col3" >0.8886</td>
#       <td id="T_8507e_row1_col4" class="data row1 col4" >0.8937</td>
#       <td id="T_8507e_row1_col5" class="data row1 col5" >0.8886</td>
#       <td id="T_8507e_row1_col6" class="data row1 col6" >0.8048</td>
#       <td id="T_8507e_row1_col7" class="data row1 col7" >0.8073</td>
#       <td id="T_8507e_row1_col8" class="data row1 col8" >0.5280</td>
#     </tr>
#     <tr>
#       <th id="T_8507e_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_8507e_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_8507e_row2_col1" class="data row2 col1" >0.8886</td>
#       <td id="T_8507e_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_8507e_row2_col3" class="data row2 col3" >0.8886</td>
#       <td id="T_8507e_row2_col4" class="data row2 col4" >0.8935</td>
#       <td id="T_8507e_row2_col5" class="data row2 col5" >0.8883</td>
#       <td id="T_8507e_row2_col6" class="data row2 col6" >0.8043</td>
#       <td id="T_8507e_row2_col7" class="data row2 col7" >0.8072</td>
#       <td id="T_8507e_row2_col8" class="data row2 col8" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_8507e_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_8507e_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_8507e_row3_col1" class="data row3 col1" >0.8841</td>
#       <td id="T_8507e_row3_col2" class="data row3 col2" >0.9095</td>
#       <td id="T_8507e_row3_col3" class="data row3 col3" >0.8841</td>
#       <td id="T_8507e_row3_col4" class="data row3 col4" >0.8912</td>
#       <td id="T_8507e_row3_col5" class="data row3 col5" >0.8843</td>
#       <td id="T_8507e_row3_col6" class="data row3 col6" >0.7992</td>
#       <td id="T_8507e_row3_col7" class="data row3 col7" >0.8025</td>
#       <td id="T_8507e_row3_col8" class="data row3 col8" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_8507e_level0_row4" class="row_heading level0 row4" >catboost</th>
#       <td id="T_8507e_row4_col0" class="data row4 col0" >CatBoost Classifier</td>
#       <td id="T_8507e_row4_col1" class="data row4 col1" >0.8841</td>
#       <td id="T_8507e_row4_col2" class="data row4 col2" >0.9180</td>
#       <td id="T_8507e_row4_col3" class="data row4 col3" >0.8841</td>
#       <td id="T_8507e_row4_col4" class="data row4 col4" >0.8943</td>
#       <td id="T_8507e_row4_col5" class="data row4 col5" >0.8849</td>
#       <td id="T_8507e_row4_col6" class="data row4 col6" >0.8002</td>
#       <td id="T_8507e_row4_col7" class="data row4 col7" >0.8043</td>
#       <td id="T_8507e_row4_col8" class="data row4 col8" >0.3980</td>
#     </tr>
#     <tr>
#       <th id="T_8507e_level0_row5" class="row_heading level0 row5" >svm</th>
#       <td id="T_8507e_row5_col0" class="data row5 col0" >SVM - Linear Kernel</td>
#       <td id="T_8507e_row5_col1" class="data row5 col1" >0.8798</td>
#       <td id="T_8507e_row5_col2" class="data

# %% [markdown]
# We will select Light Gradient Boosting Machine as model 1, Ridge Classifier as model 2, and CatBoost Classifier as model 3.

# %%
X_train_transformed, y_train_transformed = s.X_train_transformed, s.y_train_transformed
X_test_transformed, y_test_transformed = s.X_test_transformed, s.y_test_transformed

# %% [markdown]
# ## Model 1: Light Gradient Boosting Machine

# %%
model_1_tuned = s.tune_model(model_1, n_iter=500)
# Out:
# <style type="text/css">
# #T_5e3ca_row5_col0, #T_5e3ca_row5_col1, #T_5e3ca_row5_col2, #T_5e3ca_row5_col3, #T_5e3ca_row5_col4, #T_5e3ca_row5_col5, #T_5e3ca_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5e3ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e3ca_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5e3ca_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5e3ca_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5e3ca_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5e3ca_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5e3ca_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5e3ca_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e3ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e3ca_row0_col0" class="data row0 col0" >0.9333</td>
#       <td id="T_5e3ca_row0_col1" class="data row0 col1" >0.9309</td>
#       <td id="T_5e3ca_row0_col2" class="data row0 col2" >0.9333</td>
#       <td id="T_5e3ca_row0_col3" class="data row0 col3" >0.9400</td>
#       <td id="T_5e3ca_row0_col4" class="data row0 col4" >0.9317</td>
#       <td id="T_5e3ca_row0_col5" class="data row0 col5" >0.8750</td>
#       <td id="T_5e3ca_row0_col6" class="data row0 col6" >0.8821</td>
#     </tr>
#     <tr>
#       <th id="T_5e3ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5e3ca_row1_col0" class="data row1 col0" >0.8889</td>
#       <td id="T_5e3ca_row1_col1" class="data row1 col1" >0.8736</td>
#       <td id="T_5e3ca_row1_col2" class="data row1 col2" >0.8889</td>
#       <td id="T_5e3ca_row1_col3" class="data row1 col3" >0.8981</td>
#       <td id="T_5e3ca_row1_col4" class="data row1 col4" >0.8864</td>
#       <td id="T_5e3ca_row1_col5" class="data row1 col5" >0.8021</td>
#       <td id="T_5e3ca_row1_col6" class="data row1 col6" >0.8075</td>
#     </tr>
#     <tr>
#       <th id="T_5e3ca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5e3ca_row2_col0" class="data row2 col0" >0.8667</td>
#       <td id="T_5e3ca_row2_col1" class="data row2 col1" >0.9589</td>
#       <td id="T_5e3ca_row2_col2" class="data row2 col2" >0.8667</td>
#       <td id="T_5e3ca_row2_col3" class="data row2 col3" >0.8865</td>
#       <td id="T_5e3ca_row2_col4" class="data row2 col4" >0.8688</td>
#       <td id="T_5e3ca_row2_col5" class="data row2 col5" >0.7778</td>
#       <td id="T_5e3ca_row2_col6" class="data row2 col6" >0.7865</td>
#     </tr>
#     <tr>
#       <th id="T_5e3ca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5e3ca_row3_col0" class="data row3 col0" >0.8889</td>
#       <td id="T_5e3ca_row3_col1" class="data row3 col1" >0.9214</td>
#       <td id="T_5e3ca_row3_col2" class="data row3 col2" >0.8889</td>
#       <td id="T_5e3ca_row3_col3" class="data row3 col3" >0.8956</td>
#       <td id="T_5e3ca_row3_col4" class="data row3 col4" >0.8912</td>
#       <td id="T_5e3ca_row3_col5" class="data row3 col5" >0.8075</td>
#       <td id="T_5e3ca_row3_col6" class="data row3 col6" >0.8082</td>
#     </tr>
#     <tr>
#       <th id="T_5e3ca_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5e3ca_row4_col0" class="data row4 col0" >0.9545</td>
#       <td id="T_5e3ca_row4_col1" class="data row4 col1" >0.9397</td>
#       <td id="T_5e3ca_row4_col2" class="data row4 col2" >0.9545</td>
#       <td id="T_5e3ca_row4_col3" class="data row4 col3" >0.9545</td>
#       <td id="T_5e3ca_row4_col4" class="data row4 col4" >0.9545</td>
#       <td id="T_5e3ca_row4_col5" class="data row4 col5" >0.9199</td>
#       <td id="T_5e3ca_row4_col6" class="data row4 col6" >0.9199</td>
#     </tr>
#     <tr>
#       <th id="T_5e3ca_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_5e3ca_row5_col0" class="data row5 col0" >0.9065</td>
#       <td id="T_5e3ca_row5_col1" class="data row5 col1" >0.9249</td>
#       <td id="T_5e3ca_row5_col2" class="data row5 col2" >0.9065</td>
#       <td id="T_5e3ca_row5_col3" class="data row5 col3" >0.9149</td>
#       <td id="T_5e3ca_row5_col4" class="data row5 col4" >0.9065</td>
#       <td id="T_5e3ca_row5_col5" class="data row5 col5" >0.8365</td>
#       <td id="T_5e3ca_row5_col6" class="data row5 col6" >0.8408</td>
#     </tr>
#     <tr>
#       <th id="T_5e3ca_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_5e3ca_row6_col0" class="data row6 col0" >0.0324</td>
#       <td id="T_5e3ca_row6_col1" class="data row6 col1" >0.0285</td>
#       <td id="T_5e3ca_row6_col2" class="data row6 col2" >0.0324</td>
#       <td id="T_5e3ca_row6_col3" class="data row6 col3" >0.0271</td>
#       <td id="T_5e3ca_row6_col4" class="data row6 col4" >0.0316</td>
#       <td id="T_5e3ca_row6_col5" class="data row6 col5" >0.0527</td>
#       <td id="T_5e3ca_row6_col6" class="data row6 col6" >0.0511</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits

# %%
model_1_tuned_accuracy = model_1_tuned.score(X_test_transformed, y_test_transformed)
# Out:
# [LightGBM] [Warning] feature_fraction is set=1.0, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1.0
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6

# %%
pd.DataFrame(
    classification_report(
        y_test_transformed, 
        model_1_tuned.predict(X_test_transformed), 
        output_dict=True,
        target_names=s.pipeline['label_encoding'].inverse_transform(model_1_tuned.classes_)
    )
)
# Out:
# [LightGBM] [Warning] feature_fraction is set=1.0, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1.0
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
#             Insomnia  No Sleep Disorder  Sleep Apnea  accuracy   macro avg  \
# precision   0.857143           0.934783     0.833333       0.9    0.875086
# recall      0.774194           0.977273     0.806452       0.9    0.852639
# f1-score    0.813559           0.955556     0.819672       0.9    0.862929
# support    31.000000          88.000000    31.000000       0.9  150.000000
#
#            weighted avg
# precision      0.897771
# recall         0.900000
# f1-score       0.898127
# support      150.000000

# %%
ConfusionMatrixDisplay.from_estimator(
    model_1, 
    X_test_transformed, 
    y_test_transformed, 
    display_labels=s.pipeline['label_encoding'].inverse_transform(model_1_tuned.classes_)
)
plt.grid(visible=False);

# %% [markdown]
# ## Model 2: Ridge Classifier

# %%
model_2_tuned = s.tune_model(model_2, n_iter=500)
# Out:
# <style type="text/css">
# #T_fa955_row5_col0, #T_fa955_row5_col1, #T_fa955_row5_col2, #T_fa955_row5_col3, #T_fa955_row5_col4, #T_fa955_row5_col5, #T_fa955_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_fa955">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa955_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_fa955_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_fa955_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_fa955_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_fa955_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_fa955_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_fa955_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa955_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa955_row0_col0" class="data row0 col0" >0.9111</td>
#       <td id="T_fa955_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_fa955_row0_col2" class="data row0 col2" >0.9111</td>
#       <td id="T_fa955_row0_col3" class="data row0 col3" >0.9086</td>
#       <td id="T_fa955_row0_col4" class="data row0 col4" >0.9080</td>
#       <td id="T_fa955_row0_col5" class="data row0 col5" >0.8361</td>
#       <td id="T_fa955_row0_col6" class="data row0 col6" >0.8389</td>
#     </tr>
#     <tr>
#       <th id="T_fa955_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa955_row1_col0" class="data row1 col0" >0.8889</td>
#       <td id="T_fa955_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_fa955_row1_col2" class="data row1 col2" >0.8889</td>
#       <td id="T_fa955_row1_col3" class="data row1 col3" >0.8889</td>
#       <td id="T_fa955_row1_col4" class="data row1 col4" >0.8882</td>
#       <td id="T_fa955_row1_col5" class="data row1 col5" >0.8047</td>
#       <td id="T_fa955_row1_col6" class="data row1 col6" >0.8055</td>
#     </tr>
#     <tr>
#       <th id="T_fa955_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fa955_row2_col0" class="data row2 col0" >0.8889</td>
#       <td id="T_fa955_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_fa955_row2_col2" class="data row2 col2" >0.8889</td>
#       <td id="T_fa955_row2_col3" class="data row2 col3" >0.9043</td>
#       <td id="T_fa955_row2_col4" class="data row2 col4" >0.8912</td>
#       <td id="T_fa955_row2_col5" class="data row2 col5" >0.8150</td>
#       <td id="T_fa955_row2_col6" class="data row2 col6" >0.8215</td>
#     </tr>
#     <tr>
#       <th id="T_fa955_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fa955_row3_col0" class="data row3 col0" >0.8667</td>
#       <td id="T_fa955_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_fa955_row3_col2" class="data row3 col2" >0.8667</td>
#       <td id="T_fa955_row3_col3" class="data row3 col3" >0.8691</td>
#       <td id="T_fa955_row3_col4" class="data row3 col4" >0.8671</td>
#       <td id="T_fa955_row3_col5" class="data row3 col5" >0.7656</td>
#       <td id="T_fa955_row3_col6" class="data row3 col6" >0.7664</td>
#     </tr>
#     <tr>
#       <th id="T_fa955_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fa955_row4_col0" class="data row4 col0" >0.9318</td>
#       <td id="T_fa955_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_fa955_row4_col2" class="data row4 col2" >0.9318</td>
#       <td id="T_fa955_row4_col3" class="data row4 col3" >0.9307</td>
#       <td id="T_fa955_row4_col4" class="data row4 col4" >0.9305</td>
#       <td id="T_fa955_row4_col5" class="data row4 col5" >0.8779</td>
#       <td id="T_fa955_row4_col6" class="data row4 col6" >0.8788</td>
#     </tr>
#     <tr>
#       <th id="T_fa955_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_fa955_row5_col0" class="data row5 col0" >0.8975</td>
#       <td id="T_fa955_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_fa955_row5_col2" class="data row5 col2" >0.8975</td>
#       <td id="T_fa955_row5_col3" class="data row5 col3" >0.9003</td>
#       <td id="T_fa955_row5_col4" class="data row5 col4" >0.8970</td>
#       <td id="T_fa955_row5_col5" class="data row5 col5" >0.8198</td>
#       <td id="T_fa955_row5_col6" class="data row5 col6" >0.8222</td>
#     </tr>
#     <tr>
#       <th id="T_fa955_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_fa955_row6_col0" class="data row6 col0" >0.0222</td>
#       <td id="T_fa955_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_fa955_row6_col2" class="data row6 col2" >0.0222</td>
#       <td id="T_fa955_row6_col3" class="data row6 col3" >0.0205</td>
#       <td id="T_fa955_row6_col4" class="data row6 col4" >0.0212</td>
#       <td id="T_fa955_row6_col5" class="data row6 col5" >0.0369</td>
#       <td id="T_fa955_row6_col6" class="data row6 col6" >0.0371</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits

# %%
model_2_tuned_accuracy = model_2_tuned.score(X_test_transformed, y_test_transformed)

# %%
pd.DataFrame(
    classification_report(
        y_test_transformed, 
        model_2_tuned.predict(X_test_transformed), 
        output_dict=True,
        target_names=s.pipeline['label_encoding'].inverse_transform(model_2_tuned.classes_)
    )
)
# Out:
#             Insomnia  No Sleep Disorder  Sleep Apnea  accuracy   macro avg  \
# precision   0.925926           0.942529     0.750000  0.893333    0.872818
# recall      0.806452           0.931818     0.870968  0.893333    0.869746
# f1-score    0.862069           0.937143     0.805970  0.893333    0.868394
# support    31.000000          88.000000    31.000000  0.893333  150.000000
#
#            weighted avg
# precision      0.899308
# recall         0.893333
# f1-score       0.894519
# support      150.000000

# %%
ConfusionMatrixDisplay.from_estimator(
    model_2_tuned, 
    X_test_transformed, 
    y_test_transformed, 
    display_labels=s.pipeline['label_encoding'].inverse_transform(model_2_tuned.classes_)
)
plt.grid(visible=False);

# %% [markdown]
# ## Model 3: CatBoost Classifier

# %%
model_3_tuned = s.tune_model(model_3, n_iter=500)
# Out:
# <style type="text/css">
# #T_8ce45_row5_col0, #T_8ce45_row5_col1, #T_8ce45_row5_col2, #T_8ce45_row5_col3, #T_8ce45_row5_col4, #T_8ce45_row5_col5, #T_8ce45_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_8ce45">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ce45_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_8ce45_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_8ce45_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_8ce45_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_8ce45_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_8ce45_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_8ce45_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ce45_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8ce45_row0_col0" class="data row0 col0" >0.9333</td>
#       <td id="T_8ce45_row0_col1" class="data row0 col1" >0.9494</td>
#       <td id="T_8ce45_row0_col2" class="data row0 col2" >0.9333</td>
#       <td id="T_8ce45_row0_col3" class="data row0 col3" >0.9364</td>
#       <td id="T_8ce45_row0_col4" class="data row0 col4" >0.9313</td>
#       <td id="T_8ce45_row0_col5" class="data row0 col5" >0.8770</td>
#       <td id="T_8ce45_row0_col6" class="data row0 col6" >0.8808</td>
#     </tr>
#     <tr>
#       <th id="T_8ce45_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8ce45_row1_col0" class="data row1 col0" >0.9111</td>
#       <td id="T_8ce45_row1_col1" class="data row1 col1" >0.8815</td>
#       <td id="T_8ce45_row1_col2" class="data row1 col2" >0.9111</td>
#       <td id="T_8ce45_row1_col3" class="data row1 col3" >0.9159</td>
#       <td id="T_8ce45_row1_col4" class="data row1 col4" >0.9103</td>
#       <td id="T_8ce45_row1_col5" class="data row1 col5" >0.8415</td>
#       <td id="T_8ce45_row1_col6" class="data row1 col6" >0.8450</td>
#     </tr>
#     <tr>
#       <th id="T_8ce45_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8ce45_row2_col0" class="data row2 col0" >0.8667</td>
#       <td id="T_8ce45_row2_col1" class="data row2 col1" >0.9514</td>
#       <td id="T_8ce45_row2_col2" class="data row2 col2" >0.8667</td>
#       <td id="T_8ce45_row2_col3" class="data row2 col3" >0.8865</td>
#       <td id="T_8ce45_row2_col4" class="data row2 col4" >0.8688</td>
#       <td id="T_8ce45_row2_col5" class="data row2 col5" >0.7778</td>
#       <td id="T_8ce45_row2_col6" class="data row2 col6" >0.7865</td>
#     </tr>
#     <tr>
#       <th id="T_8ce45_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8ce45_row3_col0" class="data row3 col0" >0.8889</td>
#       <td id="T_8ce45_row3_col1" class="data row3 col1" >0.9097</td>
#       <td id="T_8ce45_row3_col2" class="data row3 col2" >0.8889</td>
#       <td id="T_8ce45_row3_col3" class="data row3 col3" >0.8956</td>
#       <td id="T_8ce45_row3_col4" class="data row3 col4" >0.8912</td>
#       <td id="T_8ce45_row3_col5" class="data row3 col5" >0.8075</td>
#       <td id="T_8ce45_row3_col6" class="data row3 col6" >0.8082</td>
#     </tr>
#     <tr>
#       <th id="T_8ce45_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8ce45_row4_col0" class="data row4 col0" >0.9545</td>
#       <td id="T_8ce45_row4_col1" class="data row4 col1" >0.9436</td>
#       <td id="T_8ce45_row4_col2" class="data row4 col2" >0.9545</td>
#       <td id="T_8ce45_row4_col3" class="data row4 col3" >0.9545</td>
#       <td id="T_8ce45_row4_col4" class="data row4 col4" >0.9545</td>
#       <td id="T_8ce45_row4_col5" class="data row4 col5" >0.9199</td>
#       <td id="T_8ce45_row4_col6" class="data row4 col6" >0.9199</td>
#     </tr>
#     <tr>
#       <th id="T_8ce45_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_8ce45_row5_col0" class="data row5 col0" >0.9109</td>
#       <td id="T_8ce45_row5_col1" class="data row5 col1" >0.9271</td>
#       <td id="T_8ce45_row5_col2" class="data row5 col2" >0.9109</td>
#       <td id="T_8ce45_row5_col3" class="data row5 col3" >0.9178</td>
#       <td id="T_8ce45_row5_col4" class="data row5 col4" >0.9112</td>
#       <td id="T_8ce45_row5_col5" class="data row5 col5" >0.8448</td>
#       <td id="T_8ce45_row5_col6" class="data row5 col6" >0.8481</td>
#     </tr>
#     <tr>
#       <th id="T_8ce45_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_8ce45_row6_col0" class="data row6 col0" >0.0311</td>
#       <td id="T_8ce45_row6_col1" class="data row6 col1" >0.0273</td>
#       <td id="T_8ce45_row6_col2" class="data row6 col2" >0.0311</td>
#       <td id="T_8ce45_row6_col3" class="data row6 col3" >0.0252</td>
#       <td id="T_8ce45_row6_col4" class="data row6 col4" >0.0300</td>
#       <td id="T_8ce45_row6_col5" class="data row6 col5" >0.0501</td>
#       <td id="T_8ce45_row6_col6" class="data row6 col6" >0.0482</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits

# %%
model_3_tuned_accuracy = model_3_tuned.score(X_test_transformed, y_test_transformed)

# %%
pd.DataFrame(
    classification_report(
        y_test_transformed, 
        model_3_tuned.predict(X_test_transformed), 
        output_dict=True,
        target_names=s.pipeline['label_encoding'].inverse_transform(model_3_tuned.classes_)
    )
)
# Out:
#             Insomnia  No Sleep Disorder  Sleep Apnea  accuracy   macro avg  \
# precision   0.931034           0.955556     0.870968  0.933333    0.919186
# recall      0.870968           0.977273     0.870968  0.933333    0.906403
# f1-score    0.900000           0.966292     0.870968  0.933333    0.912420
# support    31.000000          88.000000    31.000000  0.933333  150.000000
#
#            weighted avg
# precision      0.933006
# recall         0.933333
# f1-score       0.932891
# support      150.000000

# %%
ConfusionMatrixDisplay.from_estimator(
    model_3_tuned, 
    X_test_transformed, 
    y_test_transformed, 
    display_labels=s.pipeline['label_encoding'].inverse_transform(model_3_tuned.classes_)
)
plt.grid(visible=False);

# %% [markdown]
# ## Model 4: Stacked Model

# %%
model_stacked_tuned = s.stack_models([model_1_tuned, model_2_tuned, model_3_tuned])
# Out:
# <style type="text/css">
# #T_c736c_row5_col0, #T_c736c_row5_col1, #T_c736c_row5_col2, #T_c736c_row5_col3, #T_c736c_row5_col4, #T_c736c_row5_col5, #T_c736c_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c736c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c736c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_c736c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_c736c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_c736c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_c736c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_c736c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_c736c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c736c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c736c_row0_col0" class="data row0 col0" >0.9333</td>
#       <td id="T_c736c_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_c736c_row0_col2" class="data row0 col2" >0.9333</td>
#       <td id="T_c736c_row0_col3" class="data row0 col3" >0.9364</td>
#       <td id="T_c736c_row0_col4" class="data row0 col4" >0.9313</td>
#       <td id="T_c736c_row0_col5" class="data row0 col5" >0.8770</td>
#       <td id="T_c736c_row0_col6" class="data row0 col6" >0.8808</td>
#     </tr>
#     <tr>
#       <th id="T_c736c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c736c_row1_col0" class="data row1 col0" >0.8667</td>
#       <td id="T_c736c_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_c736c_row1_col2" class="data row1 col2" >0.8667</td>
#       <td id="T_c736c_row1_col3" class="data row1 col3" >0.8813</td>
#       <td id="T_c736c_row1_col4" class="data row1 col4" >0.8663</td>
#       <td id="T_c736c_row1_col5" class="data row1 col5" >0.7660</td>
#       <td id="T_c736c_row1_col6" class="data row1 col6" >0.7708</td>
#     </tr>
#     <tr>
#       <th id="T_c736c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c736c_row2_col0" class="data row2 col0" >0.8889</td>
#       <td id="T_c736c_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_c736c_row2_col2" class="data row2 col2" >0.8889</td>
#       <td id="T_c736c_row2_col3" class="data row2 col3" >0.9043</td>
#       <td id="T_c736c_row2_col4" class="data row2 col4" >0.8912</td>
#       <td id="T_c736c_row2_col5" class="data row2 col5" >0.8150</td>
#       <td id="T_c736c_row2_col6" class="data row2 col6" >0.8215</td>
#     </tr>
#     <tr>
#       <th id="T_c736c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c736c_row3_col0" class="data row3 col0" >0.8444</td>
#       <td id="T_c736c_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_c736c_row3_col2" class="data row3 col2" >0.8444</td>
#       <td id="T_c736c_row3_col3" class="data row3 col3" >0.8558</td>
#       <td id="T_c736c_row3_col4" class="data row3 col4" >0.8471</td>
#       <td id="T_c736c_row3_col5" class="data row3 col5" >0.7268</td>
#       <td id="T_c736c_row3_col6" class="data row3 col6" >0.7288</td>
#     </tr>
#     <tr>
#       <th id="T_c736c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c736c_row4_col0" class="data row4 col0" >0.9318</td>
#       <td id="T_c736c_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_c736c_row4_col2" class="data row4 col2" >0.9318</td>
#       <td id="T_c736c_row4_col3" class="data row4 col3" >0.9312</td>
#       <td id="T_c736c_row4_col4" class="data row4 col4" >0.9304</td>
#       <td id="T_c736c_row4_col5" class="data row4 col5" >0.8798</td>
#       <td id="T_c736c_row4_col6" class="data row4 col6" >0.8806</td>
#     </tr>
#     <tr>
#       <th id="T_c736c_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_c736c_row5_col0" class="data row5 col0" >0.8930</td>
#       <td id="T_c736c_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_c736c_row5_col2" class="data row5 col2" >0.8930</td>
#       <td id="T_c736c_row5_col3" class="data row5 col3" >0.9018</td>
#       <td id="T_c736c_row5_col4" class="data row5 col4" >0.8933</td>
#       <td id="T_c736c_row5_col5" class="data row5 col5" >0.8129</td>
#       <td id="T_c736c_row5_col6" class="data row5 col6" >0.8165</td>
#     </tr>
#     <tr>
#       <th id="T_c736c_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_c736c_row6_col0" class="data row6 col0" >0.0352</td>
#       <td id="T_c736c_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_c736c_row6_col2" class="data row6 col2" >0.0352</td>
#       <td id="T_c736c_row6_col3" class="data row6 col3" >0.0304</td>
#       <td id="T_c736c_row6_col4" class="data row6 col4" >0.0337</td>
#       <td id="T_c736c_row6_col5" class="data row6 col5" >0.0603</td>
#       <td id="T_c736c_row6_col6" class="data row6 col6" >0.0601</td>
#     </tr>
#   </tbody>
# </table>

# %%
model_stacked_tuned_accuracy = model_stacked_tuned.score(X_test_transformed, y_test_transformed)
# Out:
# [LightGBM] [Warning] feature_fraction is set=1.0, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1.0
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6

# %%
pd.DataFrame(
    classification_report(
        y_test_transformed, 
        model_stacked_tuned.predict(X_test_transformed), 
        output_dict=True,
        target_names=s.pipeline['label_encoding'].inverse_transform(model_stacked_tuned.classes_)
    )
)
# Out:
# [LightGBM] [Warning] feature_fraction is set=1.0, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1.0
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
#             Insomnia  No Sleep Disorder  Sleep Apnea  accuracy   macro avg  \
# precision   0.928571           0.955556     0.843750  0.926667    0.909292
# recall      0.838710           0.977273     0.870968  0.926667    0.895650
# f1-score    0.881356           0.966292     0.857143  0.926667    0.901597
# support    31.000000          88.000000    31.000000  0.926667  150.000000
#
#            weighted avg
# precision      0.926872
# recall         0.926667
# f1-score       0.926181
# support      150.000000

# %%
ConfusionMatrixDisplay.from_estimator(
    model_stacked_tuned, 
    X_test_transformed, 
    y_test_transformed, 
    display_labels=s.pipeline['label_encoding'].inverse_transform(model_stacked_tuned.classes_)
)
plt.grid(visible=False);
# Out:
# [LightGBM] [Warning] feature_fraction is set=1.0, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1.0
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6

# %% [markdown]
# ## Pycaret Summary

# %%
average = 'weighted'
baseline_wt_f1 = f1_score(y_test, baseline.predict(X_test), average=average)
tuned_wt_f1 = f1_score(y_test, rscv.best_estimator_.predict(X_test), average=average)
model_1_tuned_wt_f1 = f1_score(y_test_transformed, model_1_tuned.predict(X_test_transformed), average=average)
model_2_tuned_wt_f1 = f1_score(y_test_transformed, model_2_tuned.predict(X_test_transformed), average=average)
model_3_tuned_wt_f1 = f1_score(y_test_transformed, model_3_tuned.predict(X_test_transformed), average=average)
model_stacked_tuned_wt_f1 = f1_score(y_test_transformed, model_stacked_tuned.predict(X_test_transformed), average=average)
# Out:
# [LightGBM] [Warning] feature_fraction is set=1.0, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1.0
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# [LightGBM] [Warning] feature_fraction is set=1.0, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1.0
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6

# %%
summary_df = pd.DataFrame(
    {
        'Logistic Regression Base': [
            baseline['model'].get_params(),
            baseline_accuracy,
            baseline_wt_f1
        ],
        'Logistic Regression Tuned': [
            rscv.best_estimator_['model'].get_params(),
            tuned_accuracy,
            tuned_wt_f1
        ],
        'Pycaret Model 1 Tuned': [
            model_1_tuned.get_params(),
            model_1_tuned_accuracy,
            model_1_tuned_wt_f1
        ],
        'Pycaret Model 2 Tuned': [
            model_2_tuned.get_params(),
            model_2_tuned_accuracy,
            model_2_tuned_wt_f1
        ],
        'Pycaret Model 3 Tuned': [
            model_3_tuned.get_params(),
            model_3_tuned_accuracy,
            model_3_tuned_wt_f1
        ],
        'Pycaret Model Stacked Tuned': [
            model_stacked_tuned.get_params(),
            model_stacked_tuned_accuracy,
            model_stacked_tuned_wt_f1
        ],
    },
    index=['hyperparameters', 'accuracy', 'weighted f1']
)

summary_df
# Out:
#                                           Logistic Regression Base  \
# hyperparameters  {'C': 1.0, 'class_weight': None, 'dual': False...
# accuracy                                                  0.926667
# weighted f1                                               0.926804
#
#                                          Logistic Regression Tuned  \
# hyperparameters  {'C': 0.31489116479568624, 'class_weight': Non...
# accuracy                                                  0.926667
# weighted f1                                               0.926833
#
#                                              Pycaret Model 1 Tuned  \
# hyperparameters  {'boosting_type': 'gbdt', 'class_weight': None...
# accuracy                                                       0.9
# weighted f1                                               0.898127
#
#                                              Pycaret Model 2 Tuned  \
# hyperparameters  {'alpha': 6.78, 'class_weight': None, 'copy_X'...
# accuracy                                                  0.893333
# weighted f1                                               0.894519
#
#                                              Pycaret Model 3 Tuned  \
# hyperparameters  {'objective': 'multi:softprob', 'base_score': ...
# accuracy                                                  0.933333
# weighted f1                                               0.932891
#
#                                        Pycaret Model Stacked Tuned
# hyperparameters  {'cv': 5, 'estimators': [('Light Gradient Boos...
# accuracy                                                  0.926667
# weighted f1                                               0.926181

# %%
summary_df.to_csv('summary.csv')

# %% [markdown]
# Based from the table, tuned Model 3 (CatBoost Classifier) turned out to be the best model with accuracy of 93.33% and weighted f1 score of 93.29%.

# %%
best_model = model_3_tuned
best_model.get_params()
# Out:
# {'objective': 'multi:softprob',
#  'base_score': None,
#  'booster': 'gbtree',
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': 0.9,
#  'device': 'cpu',
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': 0.3,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': 5,
#  'max_leaves': None,
#  'min_child_weight': 3,
#  'missing': nan,
#  'monotone_constraints': None,
#  'multi_strategy': None,
#  'n_estimators': 290,
#  'n_jobs': -1,
#  'num_parallel_tree': None,
#  'random_state': 42,
#  'reg_alpha': 1,
#  'reg_lambda': 0.0005,
#  'sampling_method': None,
#  'scale_pos_weight': 31.400000000000006,
#  'subsample': 0.3,
#  'tree_method': 'auto',
#  'validate_parameters': None,
#  'verbosity': 0}

# %% [markdown]
# # Best Model Summary

# %% [markdown]
# ## Pipeline

# %%
s.pipeline
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\Deomary\AppData\Local\Temp\joblib),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(exclude=None, include=None,
#                                                transformer=LabelEncoder())),
#                 ('rare_category_grouping',
#                  TransformerWrapper(exclude=None,
#                                     include=['Gender', 'Occupation',
#                                              'BMI Category'],
#                                     transformer=RareCategoryGrouping(rare_to_value=0.02,
#                                                                      valu...
#                                                               handle_missing='return_nan',
#                                                               handle_unknown='value',
#                                                               return_df=True,
#                                                               use_cat_names=True,
#                                                               verbose=0))),
#                 ('normalize',
#                  TransformerWrapper(exclude=None, include=None,
#                                     transformer=StandardScaler(copy=True,
#                                                                with_mean=True,
#                                                                with_std=True))),
#                 ('clean_column_names',
#                  TransformerWrapper(exclude=None, include=None,
#                                     transformer=CleanColumnNames(match='[\\]\\[\\,\\{\\}\\"\\:]+')))],
#          verbose=False)

# %%
s.plot_model(best_model, 'pipeline', scale=3)

# %% [markdown]
# ## Model Hyperparameters

# %%
s.plot_model(best_model, 'parameter')
# Out:
#                                  Parameters
# objective                    multi:softprob
# base_score                             None
# booster                              gbtree
# callbacks                              None
# colsample_bylevel                      None
# colsample_bynode                       None
# colsample_bytree                        0.9
# device                                  cpu
# early_stopping_rounds                  None
# enable_categorical                    False
# eval_metric                            None
# feature_types                          None
# gamma                                  None
# grow_policy                            None
# importance_type                        None
# interaction_constraints                None
# learning_rate                           0.3
# max_bin                                None
# max_cat_threshold                      None
# max_cat_to_onehot                      None
# max_delta_step                         None
# max_depth                                 5
# max_leaves                             None
# min_child_weight                          3
# missing                                 nan
# monotone_constraints                   None
# multi_strategy                         None
# n_estimators                            290
# n_jobs                                   -1
# num_parallel_tree                      None
# random_state                             42
# reg_alpha                                 1
# reg_lambda                           0.0005
# sampling_method                        None
# scale_pos_weight         31.400000000000006
# subsample                               0.3
# tree_method                            auto
# validate_parameters                    None
# verbosity                                 0

# %% [markdown]
# ## Confusion Matrix

# %%
s.plot_model(best_model, 'confusion_matrix')

# %% [markdown]
# ## Feature Importance

# %%
s.plot_model(best_model, 'feature_all')

# %%
s.plot_model(best_model, 'feature')

# %% [markdown]
# ## Decision Boundary

# %%
s.plot_model(best_model, 'boundary')

# %% [markdown]
# ## SHAP (SHapley Additive exPlanations)

# %%
s.interpret_model(best_model, plot='summary')

# %% [markdown]
# # Pycaret Clustering

# %%
c = ClusteringExperiment()
c.setup(
    X, 
    session_id=42,
    imputation_type=None,
    normalize=True,
)
# Out:
# <style type="text/css">
# #T_6e0ff_row5_col1, #T_6e0ff_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6e0ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e0ff_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6e0ff_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e0ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e0ff_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6e0ff_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_6e0ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e0ff_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_6e0ff_row1_col1" class="data row1 col1" >(374, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_6e0ff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6e0ff_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_6e0ff_row2_col1" class="data row2 col1" >(374, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_6e0ff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6e0ff_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_6e0ff_row3_col1" class="data row3 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_6e0ff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6e0ff_row4_col0" class="data row4 col0" >Categorical features</td>
#       <td id="T_6e0ff_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6e0ff_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6e0ff_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_6e0ff_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6e0ff_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6e0ff_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_6e0ff_row6_col1" class="data row6 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6e0ff_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6e0ff_row7_col0" class="data row7 col0" >Maximum one-hot encoding</td>
#       <td id="T_6e0ff_row7_col1" class="data row7 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6e0ff_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6e0ff_row8_col0" class="data row8 col0" >Encoding method</td>
#       <td id="T_6e0ff_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6e0ff_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6e0ff_row9_col0" class="data row9 col0" >Normalize</td>
#       <td id="T_6e0ff_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6e0ff_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6e0ff_row10_col0" class="data row10 col0" >Normalize method</td>
#       <td id="T_6e0ff_row10_col1" class="data row10 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_6e0ff_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6e0ff_row11_col0" class="data row11 col0" >CPU Jobs</td>
#       <td id="T_6e0ff_row11_col1" class="data row11 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6e0ff_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6e0ff_row12_col0" class="data row12 col0" >Use GPU</td>
#       <td id="T_6e0ff_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6e0ff_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6e0ff_row13_col0" class="data row13 col0" >Log Experiment</td>
#       <td id="T_6e0ff_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6e0ff_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6e0ff_row14_col0" class="data row14 col0" >Experiment Name</td>
#       <td id="T_6e0ff_row14_col1" class="data row14 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6e0ff_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6e0ff_row15_col0" class="data row15 col0" >USI</td>
#       <td id="T_6e0ff_row15_col1" class="data row15 col1" >8d79</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 8 is the selected number of clusters as based on the elbow plot.

# %%
clusterer = c.create_model('kmodes', num_clusters=8)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5586e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5586e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5586e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5586e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5586e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5586e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5586e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5586e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5586e_row0_col0" class="data row0 col0" >0.3729</td>
#       <td id="T_5586e_row0_col1" class="data row0 col1" >51.5150</td>
#       <td id="T_5586e_row0_col2" class="data row0 col2" >1.5844</td>
#       <td id="T_5586e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5586e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5586e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Elbow Plot

# %%
c.plot_model(clusterer, 'elbow')

# %% [markdown]
# ## Pipeline

# %%
c.pipeline
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\Deomary\AppData\Local\Temp\joblib),
#          steps=[('ordinal_encoding',
#                  TransformerWrapper(exclude=None, include=['Gender'],
#                                     transformer=OrdinalEncoder(cols=['Gender'],
#                                                                drop_invariant=False,
#                                                                handle_missing='return_nan',
#                                                                handle_unknown='value',
#                                                                mapping=[{'col': 'Gender',
#                                                                          'data_type': dtype('O'),
#                                                                          'mapping': Female    0
# Male      1
# NaN      -1
# dt...
#                                     include=['Occupation', 'BMI Category'],
#                                     transformer=OneHotEncoder(cols=['Occupation',
#                                                                     'BMI '
#                                                                     'Category'],
#                                                               drop_invariant=False,
#                                                               handle_missing='return_nan',
#                                                               handle_unknown='value',
#                                                               return_df=True,
#                                                               use_cat_names=True,
#                                                               verbose=0))),
#                 ('normalize',
#                  TransformerWrapper(exclude=None, include=None,
#                                     transformer=StandardScaler(copy=True,
#                                                                with_mean=True,
#                                                                with_std=True)))],
#          verbose=False)

# %%
c.evaluate_model(clusterer)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ## 2D Cluster Plot

# %%
c.plot_model(clusterer, 'cluster')

# %% [markdown]
# ## Distribution

# %%
c.plot_model(clusterer, 'distribution')

# %% [markdown]
# ## Silhouette

# %%
c.plot_model(clusterer, 'silhouette')

# %% [markdown]
# ## Original Data appended with Cluster

# %%
clustered_df = c.assign_model(clusterer)
clustered_labeled_df = pd.concat([clustered_df, y], axis=1)
clustered_labeled_df
# Out:
#      Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0      Male   27     Software Engineer             6.1                 6
# 1      Male   28                Doctor             6.2                 6
# 2      Male   28                Doctor             6.2                 6
# 3      Male   28  Sales Representative             5.9                 4
# 4      Male   28  Sales Representative             5.9                 4
# ..      ...  ...                   ...             ...               ...
# 369  Female   59                 Nurse             8.1                 9
# 370  Female   59                 Nurse             8.0                 9
# 371  Female   59                 Nurse             8.1                 9
# 372  Female   59                 Nurse             8.1                 9
# 373  Female   59                 Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category  Heart Rate  \
# 0                         42             6   Overweight          77
# 1                         60             8       Normal          75
# 2                         60             8       Normal          75
# 3                         30             8        Obese          85
# 4                         30             8        Obese          85
# ..                       ...           ...          ...         ...
# 369                       75             3   Overweight          68
# 370                       75             3   Overweight          68
# 371                       75             3   Overweight          68
# 372                       75             3   Overweight          68
# 373                       75             3   Overweight          68
#
#      Daily Steps  bp_systolic  bp_diastolic    Cluster     Sleep Disorder
# 0           4200          126            83  Cluster 1  No Sleep Disorder
# 1          10000          125            80  Cluster 4  No Sleep Disorder
# 2          10000          125            80  Cluster 4  No Sleep Disorder
# 3           3000          140            90  Cluster 3        Sleep Apnea
# 4           3000          140            90  Cluster 3        Sleep Apnea
# ..           ...          ...           ...        ...                ...
# 369         7000          140            95  Cluster 1        Sleep Apnea
# 370         7000          140            95  Cluster 1        Sleep Apnea
# 371         7000          140            95  Cluster 1        Sleep Apnea
# 372         7000          140            95  Cluster 1        Sleep Apnea
# 373         7000          140            95  Cluster 1        Sleep Apnea
#
# [374 rows x 14 columns]

# %% [markdown]
# ## Distribution per Cluster

# %%
clusters = sorted(clustered_labeled_df['Cluster'].unique().tolist())
dataframes = [clustered_labeled_df[clustered_labeled_df['Cluster'] == x] for x in clusters]

x, axes = plt.subplots(nrows=len(clustered_labeled_df.columns), ncols=8, figsize=(30, 40), sharey='row')
axes = axes.flatten()
col_multiplied = np.array([[x, x, x, x, x, x, x, x] for x in df.columns]).reshape(-1)
for col, (index, ax)in zip(col_multiplied, enumerate(axes)):

    if (index + 1) % 8 == 1:
        df_use = dataframes[0]
        name = clusters[0]
    if (index + 1) % 8 == 2:
        df_use = dataframes[1]
        name = clusters[1]
    if (index + 1) % 8 == 3:
        df_use = dataframes[2]
        name = clusters[2]
    if (index + 1) % 8 == 4:
        df_use = dataframes[3]
        name = clusters[3]

    if (index + 1) % 8 == 5:
        df_use = dataframes[4]
        name = clusters[4]
    if (index + 1) % 8 == 6:
        df_use = dataframes[5]
        name = clusters[5]
    if (index + 1) % 8 == 7:
        df_use = dataframes[6]
        name = clusters[6]
    if (index + 1) % 8 == 0:
        df_use = dataframes[7]
        name = clusters[7]


    if (df_use[col].dtype == 'int64') or (df_use[col].dtype == 'float64'):
        bins = 20
    else:
        bins = 'auto'

    sns.histplot(df_use, x=col, ax=ax, bins=bins)
    ax.set_ylabel(col, fontsize=10)
    ax.set_xlabel(name, fontsize=10)
    ax.tick_params(axis='x', labelrotation=45, labelsize=6)
    ax.grid(False)

    for label in ax.get_xticklabels():
        label.set_horizontalalignment('right')



plt.tight_layout()

# %%
onehotencoder2 = ColumnTransformer(
    [
        (
            'onehotencoder', 
            OneHotEncoder(
                handle_unknown='infrequent_if_exist', 
                sparse_output=False,
                min_frequency=0.02
            ), 
            [col for col in df.columns if df[col].dtype == 'object']
        ),
    ],
    remainder='passthrough'
).set_output(transform='pandas')

# %%
cluster_summary = pd.concat(
    [
        StandardScaler().set_output(transform='pandas').fit_transform(onehotencoder2.fit_transform(df)), 
        clustered_df['Cluster']
    ], 
    axis=1
).groupby('Cluster').mean().T

cluster_summary.to_csv('cluster_summary.csv')
cluster_summary
# Out:
# Cluster                                          Cluster 0  Cluster 1  \
# onehotencoder__Gender_Female                     -0.962333   0.982180
# onehotencoder__Gender_Male                        0.962333  -0.982180
# onehotencoder__Occupation_Accountant             -0.331349  -0.331349
# onehotencoder__Occupation_Doctor                 -0.173948  -0.484070
# onehotencoder__Occupation_Engineer                0.235949  -0.450080
# onehotencoder__Occupation_Lawyer                  1.414664  -0.379119
# onehotencoder__Occupation_Nurse                  -0.492468   1.922457
# onehotencoder__Occupation_Salesperson            -0.305888  -0.305888
# onehotencoder__Occupation_Teacher                -0.346064  -0.346064
# onehotencoder__Occupation_infrequent_sklearn     -0.014114   0.079578
# onehotencoder__BMI Category_Normal                0.822837  -1.043736
# onehotencoder__BMI Category_Normal Weight        -0.126505  -0.181851
# onehotencoder__BMI Category_Obese                 0.001792  -0.165748
# onehotencoder__BMI Category_Overweight           -0.781604   1.206516
# onehotencoder__Sleep Disorder_Insomnia           -0.375492  -0.473845
# onehotencoder__Sleep Disorder_No Sleep Disorder   0.621833  -0.956663
# onehotencoder__Sleep Disorder_Sleep Apnea        -0.380288   1.631580
# remainder__Age                                   -0.398863   1.182710
# remainder__Sleep Duration                         0.536152  -0.114092
# remainder__Quality of Sleep                       0.450508   0.060969
# remainder__Physical Activity Level                0.760896   0.986139
# remainder__Stress Level                          -0.186763   0.097123
# remainder__Heart Rate                            -0.131752   0.433730
# remainder__Daily Steps                            0.643609   0.843666
# remainder__bp_systolic                           -0.036601   1.351918
# remainder__bp_diastolic                          -0.083629   1.540431
#
# Cluster                                          Cluster 2  Cluster 3  \
# onehotencoder__Gender_Female                      0.775445  -0.989361
# onehotencoder__Gender_Male                       -0.775445   0.989361
# onehotencoder__Occupation_Accountant              0.456725  -0.331349
# onehotencoder__Occupation_Doctor                 -0.184083   0.790874
# onehotencoder__Occupation_Engineer               -0.135739  -0.450080
# onehotencoder__Occupation_Lawyer                 -0.201659  -0.379119
# onehotencoder__Occupation_Nurse                   0.249607  -0.492468
# onehotencoder__Occupation_Salesperson            -0.305888  -0.305888
# onehotencoder__Occupation_Teacher                -0.346064   0.058398
# onehotencoder__Occupation_infrequent_sklearn      0.870388   2.045412
# onehotencoder__BMI Category_Normal               -1.043736  -1.043736
# onehotencoder__BMI Category_Normal Weight         3.333381  -0.243906
# onehotencoder__BMI Category_Obese                -0.165748   6.033241
# onehotencoder__BMI Category_Overweight           -0.448362  -0.809239
# onehotencoder__Sleep Disorder_Insomnia           -0.218218   0.727393
# onehotencoder__Sleep Disorder_No Sleep Disorder   0.363653  -1.188656
# onehotencoder__Sleep Disorder_Sleep Apnea        -0.223762   0.717354
# remainder__Age                                   -0.299746  -0.439817
# remainder__Sleep Duration                        -0.084798  -0.355007
# remainder__Quality of Sleep                      -0.261708  -0.889137
# remainder__Physical Activity Level               -0.081745  -0.260594
# remainder__Stress Level                           0.081474   0.276485
# remainder__Heart Rate                             0.686229   3.440371
# remainder__Daily Steps                           -0.330801  -2.137919
# remainder__bp_systolic                           -0.649292   1.511618
# remainder__bp_diastolic                          -0.564449   0.991370
#
# Cluster                                          Cluster 4  Cluster 5  \
# onehotencoder__Gender_Female                     -0.308471   0.844077
# onehotencoder__Gender_Male                        0.308471  -0.844077
# onehotencoder__Occupation_Accountant             -0.331349   2.180636
# onehotencoder__Occupation_Doctor                  1.035013  -0.484070
# onehotencoder__Occupation_Engineer                0.630052  -0.301641
# onehotencoder__Occupation_Lawyer                 -0.379119  -0.379119
# onehotencoder__Occupation_Nurse                  -0.492468  -0.422383
# onehotencoder__Occupation_Salesperson            -0.305888  -0.305888
# onehotencoder__Occupation_Teacher                -0.346064   0.193219
# onehotencoder__Occupation_infrequent_sklearn     -0.174078  -0.174078
# onehotencoder__BMI Category_Normal                0.958096   0.735671
# onehotencoder__BMI Category_Normal Weight        -0.243906   0.238744
# onehotencoder__BMI Category_Obese                -0.165748  -0.165748
# onehotencoder__BMI Category_Overweight           -0.809239  -0.809239
# onehotencoder__Sleep Disorder_Insomnia           -0.456555  -0.440477
# onehotencoder__Sleep Disorder_No Sleep Disorder   0.754906   0.728512
# onehotencoder__Sleep Disorder_Sleep Apnea        -0.460966  -0.444964
# remainder__Age                                   -0.394680  -0.627429
# remainder__Sleep Duration                         0.271569   0.095958
# remainder__Quality of Sleep                       0.067581   0.574864
# remainder__Physical Activity Level               -0.750245   0.053197
# remainder__Stress Level                           0.094893  -0.750201
# remainder__Heart Rate                            -0.374988  -0.510931
# remainder__Daily Steps                           -0.485799   0.130548
# remainder__bp_systolic                           -0.658593  -1.686986
# remainder__bp_diastolic                          -0.755640  -1.495975
#
# Cluster                                          Cluster 6  Cluster 7
# onehotencoder__Gender_Female                     -0.625704   0.752674
# onehotencoder__Gender_Male                        0.625704  -0.752674
# onehotencoder__Occupation_Accountant              0.125375  -0.331349
# onehotencoder__Occupation_Doctor                 -0.484070  -0.484070
# onehotencoder__Occupation_Engineer               -0.328630  -0.450080
# onehotencoder__Occupation_Lawyer                 -0.241991  -0.379119
# onehotencoder__Occupation_Nurse                  -0.492468  -0.492468
# onehotencoder__Occupation_Salesperson             2.294157  -0.305888
# onehotencoder__Occupation_Teacher                -0.198987   2.889637
# onehotencoder__Occupation_infrequent_sklearn     -0.174078  -0.174078
# onehotencoder__BMI Category_Normal               -1.043736  -1.043736
# onehotencoder__BMI Category_Normal Weight        -0.243906  -0.243906
# onehotencoder__BMI Category_Obese                -0.165748  -0.165748
# onehotencoder__BMI Category_Overweight            1.235729   1.235729
# onehotencoder__Sleep Disorder_Insomnia            1.570508   1.565068
# onehotencoder__Sleep Disorder_No Sleep Disorder  -1.004116  -0.926728
# onehotencoder__Sleep Disorder_Sleep Apnea        -0.345514  -0.433936
# remainder__Age                                    0.256837   0.120223
# remainder__Sleep Duration                        -0.812646  -0.665574
# remainder__Quality of Sleep                      -0.946176  -0.369653
# remainder__Physical Activity Level               -0.664820  -0.774247
# remainder__Stress Level                           0.885657  -0.563117
# remainder__Heart Rate                             0.587179  -1.032059
# remainder__Daily Steps                           -0.575882  -0.569438
# remainder__bp_systolic                            0.163446   0.724734
# remainder__bp_diastolic                           0.042149   0.743670

# %% [markdown]
# For summarized version of the characteristics of different clusters, see **cluster_summary.csv.**
